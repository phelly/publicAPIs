# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas_profiling 
from pandas_profiling import ProfileReport as pp

# %%
#importing datasets
train_df = pd.read_csv("Train.csv")
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4809 entries, 0 to 4808
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     4809 non-null   object
#  1   country                4809 non-null   object
#  2   age_group              4809 non-null   object
#  3   travel_with            3695 non-null   object
#  4   total_female           4806 non-null   float64
#  5   total_male             4804 non-null   float64
#  6   purpose                4809 non-null   object
#  7   main_activity          4809 non-null   object
#  8   info_source            4809 non-null   object
#  9   tour_arrangement       4809 non-null   object
#  10  package_transport_int  4809 non-null   object
#  11  package_accomodation   4809 non-null   object
#  12  package_food           4809 non-null   object
#  13  package_transport_tz   4809 non-null   object
# ...

# %%
train_df.shape
# Out:
# (4809, 23)

# %%
#test data
test_df = pd.read_csv('Test.csv')
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     1601 non-null   object
#  1   country                1601 non-null   object
#  2   age_group              1601 non-null   object
#  3   travel_with            1274 non-null   object
#  4   total_female           1600 non-null   float64
#  5   total_male             1599 non-null   float64
#  6   purpose                1601 non-null   object
#  7   main_activity          1601 non-null   object
#  8   info_source            1601 non-null   object
#  9   tour_arrangement       1601 non-null   object
#  10  package_transport_int  1601 non-null   object
#  11  package_accomodation   1601 non-null   object
#  12  package_food           1601 non-null   object
#  13  package_transport_tz   1601 non-null   object
# ...

# %%
X = train_df.drop(['total_cost'], axis =1)
y = train_df['total_cost']

# %%
X.head()
# Out:
#           ID         country age_group        travel_with  total_female  \
# 0     tour_0      SWIZERLAND     45-64  Friends/Relatives           1.0
# 1    tour_10  UNITED KINGDOM     25-44                NaN           1.0
# 2  tour_1000  UNITED KINGDOM     25-44              Alone           0.0
# 3  tour_1002  UNITED KINGDOM     25-44             Spouse           1.0
# 4  tour_1004           CHINA      1-24                NaN           1.0
#
#    total_male                         purpose     main_activity  \
# 0         1.0            Leisure and Holidays  Wildlife tourism
# 1         0.0            Leisure and Holidays  Cultural tourism
# 2         1.0  Visiting Friends and Relatives  Cultural tourism
# 3         1.0            Leisure and Holidays  Wildlife tourism
# 4         0.0            Leisure and Holidays  Wildlife tourism
#
#                     info_source tour_arrangement  ... package_food  \
# 0            Friends, relatives      Independent  ...           No
# ...

# %%
## Feature Extraction
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4809 entries, 0 to 4808
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     4809 non-null   object
#  1   country                4809 non-null   object
#  2   age_group              4809 non-null   object
#  3   travel_with            3695 non-null   object
#  4   total_female           4806 non-null   float64
#  5   total_male             4804 non-null   float64
#  6   purpose                4809 non-null   object
#  7   main_activity          4809 non-null   object
#  8   info_source            4809 non-null   object
#  9   tour_arrangement       4809 non-null   object
#  10  package_transport_int  4809 non-null   object
#  11  package_accomodation   4809 non-null   object
#  12  package_food           4809 non-null   object
#  13  package_transport_tz   4809 non-null   object
# ...

# %%
#We will need to encode categorical data 
# Frequency encoding and onehot encoder
main_fe = X.groupby('main_activity').size()/len(X)
X.loc[:, 'main_activity_fe'] = X['main_activity'].map(main_fe)

# %%
payment = X.groupby('payment_mode').size()/len(X)
X.loc[:, 'payment_mode_fe'] = X['payment_mode'].map(payment)

# %%
purposee = X.groupby('purpose').size()/len(X)
X.loc[:, 'purpose_fe'] = X['purpose'].map(purposee)

# %%
country_size = X['country'].value_counts()
country_size
# Out:
# UNITED STATES OF AMERICA    695
# UNITED KINGDOM              533
# ITALY                       393
# FRANCE                      280
# ZIMBABWE                    274
#                            ...
# TRINIDAD TOBACCO              1
# LESOTHO                       1
# CYPRUS                        1
# MADAGASCAR                    1
# GEORGIA                       1
# Name: country, Length: 105, dtype: int64

# %%
country_fe = X.groupby('country').size()/len(X)
X.loc[:, 'country_fe'] = X['country'].map(country_fe)

# %%
X.head(3)
# Out:
#           ID         country age_group        travel_with  total_female  \
# 0     tour_0      SWIZERLAND     45-64  Friends/Relatives           1.0
# 1    tour_10  UNITED KINGDOM     25-44                NaN           1.0
# 2  tour_1000  UNITED KINGDOM     25-44              Alone           0.0
#
#    total_male                         purpose     main_activity  \
# 0         1.0            Leisure and Holidays  Wildlife tourism
# 1         0.0            Leisure and Holidays  Cultural tourism
# 2         1.0  Visiting Friends and Relatives  Cultural tourism
#
#           info_source tour_arrangement  ... package_insurance night_mainland  \
# 0  Friends, relatives      Independent  ...                No           13.0
# 1              others      Independent  ...                No           14.0
# 2  Friends, relatives      Independent  ...                No            1.0
#
#   night_zanzibar payment_mode first_trip_tz  \
# 0            0.0         Cash            No
# ...

# %%
most_impressing_fe = X.groupby('most_impressing').size()/len(X)
X.loc[:,'most_impressing_fe'] = X['most_impressing'].map(most_impressing_fe)

# %%
X = pd.get_dummies(X, prefix = ["first_trip"], columns = ['first_trip_tz'])
X.head(3)
# Out:
#           ID         country age_group        travel_with  total_female  \
# 0     tour_0      SWIZERLAND     45-64  Friends/Relatives           1.0
# 1    tour_10  UNITED KINGDOM     25-44                NaN           1.0
# 2  tour_1000  UNITED KINGDOM     25-44              Alone           0.0
#
#    total_male                         purpose     main_activity  \
# 0         1.0            Leisure and Holidays  Wildlife tourism
# 1         0.0            Leisure and Holidays  Cultural tourism
# 2         1.0  Visiting Friends and Relatives  Cultural tourism
#
#           info_source tour_arrangement  ... night_zanzibar payment_mode  \
# 0  Friends, relatives      Independent  ...            0.0         Cash
# 1              others      Independent  ...            7.0         Cash
# 2  Friends, relatives      Independent  ...           31.0         Cash
#
#                         most_impressing main_activity_fe payment_mode_fe  \
# ...

# %%
X = pd.get_dummies(X, prefix = ["tour_arrangement"], columns = ['tour_arrangement'])
X.head(2)
# Out:
#         ID         country age_group        travel_with  total_female  \
# 0   tour_0      SWIZERLAND     45-64  Friends/Relatives           1.0
# 1  tour_10  UNITED KINGDOM     25-44                NaN           1.0
#
#    total_male               purpose     main_activity         info_source  \
# 0         1.0  Leisure and Holidays  Wildlife tourism  Friends, relatives
# 1         0.0  Leisure and Holidays  Cultural tourism              others
#
#   package_transport_int  ...                       most_impressing  \
# 0                    No  ...                       Friendly People
# 1                    No  ...  Wonderful Country, Landscape, Nature
#
#   main_activity_fe payment_mode_fe purpose_fe country_fe most_impressing_fe  \
# 0         0.469744         0.86754   0.590559   0.013308           0.320441
# 1         0.074652         0.86754   0.590559   0.110834           0.105427
#
#    first_trip_No  first_trip_Yes tour_arrangement_Independent  \
# ...

# %%
info_source_fe = X.groupby('info_source').size()/len(X)
X.loc[:,'info_source_fe'] = X['info_source'].map(info_source_fe)

# %%
X = pd.get_dummies(X, prefix = ["package_food"], columns = ['package_food'])
X.head(2)
# Out:
#         ID         country age_group        travel_with  total_female  \
# 0   tour_0      SWIZERLAND     45-64  Friends/Relatives           1.0
# 1  tour_10  UNITED KINGDOM     25-44                NaN           1.0
#
#    total_male               purpose     main_activity         info_source  \
# 0         1.0  Leisure and Holidays  Wildlife tourism  Friends, relatives
# 1         0.0  Leisure and Holidays  Cultural tourism              others
#
#   package_transport_int  ... purpose_fe country_fe most_impressing_fe  \
# 0                    No  ...   0.590559   0.013308           0.320441
# 1                    No  ...   0.590559   0.110834           0.105427
#
#   first_trip_No first_trip_Yes  tour_arrangement_Independent  \
# 0             1              0                             1
# 1             0              1                             1
#
#    tour_arrangement_Package Tour info_source_fe package_food_No  \
# ...

# %%
X = pd.get_dummies(X, prefix = ["package_accomodation"], columns = ['package_accomodation'])
X.head(2)
# Out:
#         ID         country age_group        travel_with  total_female  \
# 0   tour_0      SWIZERLAND     45-64  Friends/Relatives           1.0
# 1  tour_10  UNITED KINGDOM     25-44                NaN           1.0
#
#    total_male               purpose     main_activity         info_source  \
# 0         1.0  Leisure and Holidays  Wildlife tourism  Friends, relatives
# 1         0.0  Leisure and Holidays  Cultural tourism              others
#
#   package_transport_int  ... most_impressing_fe first_trip_No first_trip_Yes  \
# 0                    No  ...           0.320441             1              0
# 1                    No  ...           0.105427             0              1
#
#   tour_arrangement_Independent  tour_arrangement_Package Tour  info_source_fe  \
# 0                            1                              0        0.339988
# 1                            1                              0        0.101892
#
# ...

# %%
X = pd.get_dummies(X, prefix = ["package_transport"], columns = ['package_transport_tz'])
X.head(2)
# Out:
#         ID         country age_group        travel_with  total_female  \
# 0   tour_0      SWIZERLAND     45-64  Friends/Relatives           1.0
# 1  tour_10  UNITED KINGDOM     25-44                NaN           1.0
#
#    total_male               purpose     main_activity         info_source  \
# 0         1.0  Leisure and Holidays  Wildlife tourism  Friends, relatives
# 1         0.0  Leisure and Holidays  Cultural tourism              others
#
#   package_transport_int  ... first_trip_Yes tour_arrangement_Independent  \
# 0                    No  ...              0                            1
# 1                    No  ...              1                            1
#
#   tour_arrangement_Package Tour  info_source_fe  package_food_No  \
# 0                             0        0.339988                1
# 1                             0        0.101892                1
#
#   package_food_Yes package_accomodation_No  package_accomodation_Yes  \
# ...

# %%
X = pd.get_dummies(X, prefix = ["package_guidetour"], columns = ['package_guided_tour'])

# %%
X = pd.get_dummies(X, prefix = ["package_insurance"], columns = ['package_insurance'])

# %%
X = pd.get_dummies(X, prefix = ["package_sightseeing"], columns = ['package_sightseeing'])

# %%
travel_with_fe = X.groupby('travel_with').size()/len(X)
X.loc[:, 'travel_with_fe'] = X['travel_with'].map(travel_with_fe)

# %%
age_group_fe = X.groupby('age_group').size()/len(X)
X.loc[:, 'age_group_fe'] = X['age_group'].map(age_group_fe)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4809 entries, 0 to 4808
# Data columns (total 38 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   ID                             4809 non-null   object
#  1   country                        4809 non-null   object
#  2   age_group                      4809 non-null   object
#  3   travel_with                    3695 non-null   object
#  4   total_female                   4806 non-null   float64
#  5   total_male                     4804 non-null   float64
#  6   purpose                        4809 non-null   object
#  7   main_activity                  4809 non-null   object
#  8   info_source                    4809 non-null   object
#  9   package_transport_int          4809 non-null   object
#  10  night_mainland                 4809 non-null   float64
#  11  night_zanzibar                 4809 non-null   float64
# ...
